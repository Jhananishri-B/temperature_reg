# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
df=pd.read_csv("cleaned_data.csv")

# %%
col=['LandMaxTemperature']
for i in col:
    plt.figure(figsize=(8,6))
    sns.histplot(df[i], kde=True,color='red')
    plt.title(f"Distribution of {i}")
    plt.show()
    print("skewness:",df[i].skew())
# Out:
# skewness: -0.09693800875125953

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
col_drop=['LandAndOceanAverageTemperature','LandAndOceanAverageTemperatureUncertainty','LandAverageTemperatureUncertainty','Unnamed: 0']

# %%
df.shape
# Out:
# (1992, 10)
